# %%
import tushare as ts
import pymongo
from datetime import datetime, timedelta
from vnpy.trader.vtObject import VtTickData
from vnpy.trader.app.ctaStrategy.ctaBase import TICK_DB_NAME

# %%
'''
下载历史tick数据
'''
#合约代码
code = '600380'
exchange = 'SSE'
vtCode = code + '.' + exchange

#起始时间
startDate = '2017-11-09'
date = datetime.strptime(startDate, '%Y-%m-%d')
delta = timedelta(1)

#获取数据库
client = pymongo.MongoClient('localhost', 27017)
collection = client[TICK_DB_NAME][vtCode]
collection.create_index('datetime')

stop = False
while not stop:
    tickData = ts.get_tick_data(code, date.strftime('%Y-%m-%d'))
    if len(tickData) > 10:
        #排除数据有误或者当天没有数据的情况
        for index, row in tickData.iterrows():
            tick = VtTickData()
            tick.date = date.strftime('%Y-%m-%d')
            tick.time = row['time']
            tick.datetime = datetime.strptime(tick.date + ' ' + tick.time, '%Y-%m-%d %H:%M:%S')
    
            tick.symbol = code
            tick.exchange = exchange
            tick.vcSymbol = vtCode
    
            tick.lastprice = row['price']
            tick.lastvolume = row['volume']
    
            collection.update_many({'datetime':tick.datetime}, {'$set':tick.__dict__}, upsert = True)
    if date.date() < datetime.now().date():
        date = date + delta
    else:
        stop = True
    print tickData
# Out:
#           time  price change  volume   amount type
# 0     15:00:00  13.47     --       0        0   买盘
# 1     15:00:00  13.47     --     164   220908   买盘
# 2     15:00:00  13.47   0.01     249   335403   买盘
# 3     14:59:57  13.46     --     901  1212746   卖盘
# 4     14:59:54  13.46  -0.02     698   939508   卖盘
# 5     14:59:51  13.48   0.01     542   730616   买盘
# 6     14:59:48  13.47     --     224   301728   卖盘
# 7     14:59:45  13.47     --     573   771831   卖盘
# 8     14:59:42  13.47     --     158   212826   卖盘
# 9     14:59:39  13.47     --     318   428346   卖盘
# 10    14:59:36  13.47     --     417   561699   卖盘
# 11    14:59:33  13.47   0.01     442   595374   买盘
# 12    14:59:30  13.46  -0.01    1343  1807678  中性盘
# 13    14:59:27  13.47   0.01    1440  1939680   买盘
# 14    14:59:24  13.46  -0.01     386   520094   卖盘
# 15    14:59:21  13.47     --     126   169722   买盘
# 16    14:59:18  13.47     --     212   285564   买盘
# 17    14:59:15  13.47  -0.01     303   408141  中性盘
# 18    14:59:12  13.48   0.01     188   253424   买盘
# 19    14:59:09  13.47  -0.01    1200  1616400  中性盘
# 20    14:59:06  13.48     --     573   772404   买盘
# 21    14:59:03  13.48     --     486   655128   买盘
# 22    14:59:00  13.48     --     603   812844   买盘
# 23    14:58:57  13.48     --     650   876200   买盘
# 24    14:58:54  13.48     --     753  1015044   卖盘
# 25    14:58:51  13.48  -0.01     251   338348   卖盘
# 26    14:58:48  13.49     --     871  1174979   买盘
# 14    14:59:23  13.36     --     247   329992   买盘
# 15    14:59:20  13.36     --      69    92184   买盘
# 16    14:59:17  13.36     --     313   418168   卖盘
# 17    14:59:14  13.36     --     339   452904   买盘
# 18    14:59:11  13.36     --     396   529056   卖盘
# 19    14:59:08  13.36     --     473   631928   卖盘
# 20    14:59:05  13.36  -0.01     402   537072   卖盘
# 21    14:59:02  13.37     --     173   231301   买盘
# 22    14:58:59  13.37     --     254   339598   买盘
# 23    14:58:56  13.37  -0.01     290   387730   买盘
# 24    14:58:53  13.38     --     636   850968   买盘
# 25    14:58:50  13.38     --     386   516468   买盘
# 26    14:58:47  13.38     --      40    53520   买盘
# 27    14:58:44  13.38     --     765  1023570   买盘
# 28    14:58:41  13.38     --      95   127110   买盘
# 29    14:58:38  13.38     --      27    36126   买盘
# ...        ...    ...    ...     ...      ...  ...
# 4607  09:31:22  13.37   0.02     354   473298   买盘
# 4608  09:31:19  13.35  -0.01     349   465915   卖盘
# 4609  09:31:16  13.36  -0.02     135   180360   卖盘
# 4610  09:31:13  13.38   0.01     387   517806   买盘
# 4611  09:31:10  13.37  -0.01      63    84231  中性盘
# 4612  09:31:07  13.38   0.02     427   571326   买盘
# 4613  09:31:04  13.36     --     130   173680   卖盘
# 4614  09:31:01  13.36  -0.01     420   561120   卖盘
# 4615  09:30:58  13.37  -0.03     202   270074   卖盘
# 4616  09:30:55  13.40     --    1625  2178263   买盘
# 4617  09:30:52  13.40     --    1050  1407000   买盘
# 4618  09:30:49  13.40     --     139   186260   买盘
# 4619  09:30:46  13.40  -0.01     536   718240   卖盘
# 4620  09:30:43  13.41     --     749  1004409   卖盘
# 4621  09:30:40  13.41  -0.01     901  1208241   卖盘
# 4622  09:30:37  13.42   0.01     160   214720   买盘
# 4623  09:30:34  13.41   0.01     296   396936   卖盘
# 4624  09:30:31  13.40   0.01     329   440860  中性盘
# 4625  09:30:28  13.39  -0.01     267   358088   卖盘
# 4626  09:30:25  13.40     --     240   321600   卖盘
# 4627  09:30:22  13.40   0.01     381   510540   买盘
# 4628  09:30:19  13.39     --     223   298597   卖盘
# 4629  09:30:16  13.39     --     139   186121   卖盘
# 4630  09:30:13  13.39  -0.01       8    10712   卖盘
# 4631  09:30:10  13.40   0.04     151   202340   买盘
# 4632  09:30:07  13.36  -0.02    1431  1912350   卖盘
# 4633  09:30:04  13.38   0.03    3622  4846236   买盘
# 4634  09:30:01  13.35     --      28    37380   卖盘
# 4635  09:29:00  13.35     --       0        0   卖盘
# 4636  09:25:02  13.35  13.35    3114  4157470   买盘
#
# [4637 rows x 6 columns]

# %%
tick = ts.get_tick_data('600380', '2017-01-06')
tick
