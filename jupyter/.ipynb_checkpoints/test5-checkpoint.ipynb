# %%
import tushare as ts
import pandas as pd
from datetime import datetime, timedelta
import pymongo
import time
from vnpy.trader.app.ctaStrategy.ctaBase import TICK_DB_NAME

# %%
code = '600380'
dbName = 'Stocks_Daily_Db'

# %%
codeList = ts.get_stock_basics()
codeList

# %%
date = datetime.now()
hour = date.strftime('%H')
oneDay = timedelta(1)

if int(hour) < 15:
    date = date - oneDay
    
dateStr = date.strftime('%Y-%m-%d')

# %%
data = ts.get_hist_data('300680', retry_count = 10, pause = 1)
#data.sort_index(inplace = True)
#data

# %%
#vnpy 1.7.0有的
from vnpy.trader.app.ctaStrategy.strategy import strategyAtrRsi
from vnpy.trader.app.ctaStrategy.strategy import strategyKingKeltner
from vnpy.trader.app.ctaStrategy.strategy import strategyDualThrust

#vnpy 1.7.0没有的
#from vnpy.trader.app.ctaStrategy.strategy import strategyDoubleMa
#from vnpy.trader.app.ctaStrategy.strategy import strategyBollChannel

# %%
class abc(object):
    def __init__(self, name):
        self.__name = name;
        
    def action(self):
        print self.__name
        print 'yes'

the = abc('pika')
the._abc__name = 'ok'
the.action()
# Out:
# ok
# yes

# %%
a = 1.68621
b = round(a, 2)
b
# Out:
# 1.69

# %%
a = [1,2,3,4,5,6]
print a
a.pop()
print a[]
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5]

# %%
a = datetime.now()
print type(a.date())
# Out:
# <type 'datetime.date'>

# %%
a = time.time()
time.sleep(1)
b = time.time()
c = b-a
c
# Out:
# 1.0

# %%
a = datetime.now()
print a.date()
print a.time()
print type(a.date)
# Out:
# 2017-11-10
# 16:25:21.037000
# <type 'builtin_function_or_method'>

# %%
bar = ts.get_tick_data('600380', '2017-01-03')
bar
# Out:
#           time  price change  volume  amount type
# 0     15:00:00  10.02     --       0       0   卖盘
# 1     15:00:00  10.02  -0.01       0       0   卖盘
# 2     14:59:54  10.03   0.01       8    8023   买盘
# 3     14:59:51  10.02     --       5    5010   卖盘
# 4     14:59:45  10.02     --      26   26052   买盘
# 5     14:59:42  10.02     --      12   12024   买盘
# 6     14:59:39  10.02   0.01       8    8016   买盘
# 7     14:59:30  10.01  -0.01       4    4004   卖盘
# 8     14:59:21  10.02     --      88   88176   卖盘
# 9     14:59:18  10.02     --      10   10020   卖盘
# 10    14:59:12  10.02     --       4    4008   卖盘
# 11    14:59:09  10.02     --     100  100200   卖盘
# 12    14:59:05  10.02   0.01     102  102204   买盘
# 13    14:59:02  10.01  -0.01      31   31031   卖盘
# 14    14:59:00  10.02     --       8    8016   买盘
# 15    14:58:57  10.02     --     400  400800   买盘
# 16    14:58:54  10.02   0.01       3    3006   买盘
# 17    14:58:39  10.01  -0.01      10   10010   卖盘
# 18    14:58:36  10.02   0.01     116  116232   买盘
# 19    14:58:27  10.01     --       2    2002   卖盘
# 20    14:58:18  10.01     --     382  382382   买盘
# 21    14:58:15  10.01     --      10   10010   买盘
# 22    14:58:12  10.01     --      10   10010   买盘
# 23    14:58:06  10.01     --       2    2002   买盘
# 24    14:58:03  10.01     --      24   24024   买盘
# 25    14:58:00  10.01     --      48   48048   买盘
# 26    14:57:53  10.01     --      24   24024   卖盘
# 27    14:57:50  10.01     --      85   85085   卖盘
# 28    14:57:47  10.01  -0.01       5    5005   卖盘
# 29    14:57:44  10.02     --      52   52104   买盘
# ...        ...    ...    ...     ...     ...  ...
# 1227  09:33:28   9.97     --      51   50847   卖盘
# 1228  09:33:22   9.97     --       0       0  中性盘
# 1229  09:33:19   9.97   0.01      10    9970   买盘
# 1230  09:33:16   9.96  -0.01     214  213144   卖盘
# 1231  09:33:07   9.97     --       5    4985   买盘
# 1232  09:33:04   9.97     --      30   29910   买盘
# 1233  09:32:55   9.97   0.01      77   76769   买盘
# 1234  09:32:43   9.96     --      46   45816   卖盘
# 1235  09:32:40   9.96  -0.01      30   29880   卖盘
# 1236  09:32:19   9.97   0.01       8    7976   买盘
# 1237  09:32:16   9.96  -0.01     100   99600   卖盘
# 1238  09:32:13   9.97     --      20   19940   买盘
# 1239  09:32:04   9.97   0.01       6    5982   买盘
# 1240  09:31:49   9.96     --      13   12948   买盘
# 1241  09:31:43   9.96     --       3    2988   买盘
# 1242  09:31:37   9.96  -0.01      13   12948   卖盘
# 1243  09:31:31   9.97     --      10    9970   买盘
# 1244  09:31:10   9.97     --      13   12961   卖盘
# 1245  09:30:52   9.97     --      15   14955   卖盘
# 1246  09:30:49   9.97     --       0       0   卖盘
# 1247  09:30:43   9.97  -0.02       2    1994   卖盘
# 1248  09:30:34   9.99     --       0       0   买盘
# 1249  09:30:31   9.99   0.04      11   10989   买盘
# 1250  09:30:28   9.95     --      30   29849   卖盘
# 1251  09:30:19   9.95     --      29   28854   卖盘
# 1252  09:30:10   9.95  -0.01      50   49750   卖盘
# 1253  09:30:07   9.96     --       9    8964   卖盘
# 1254  09:30:04   9.96   0.02     159  158364   买盘
# 1255  09:29:00   9.94     --       0       0   卖盘
# 1256  09:25:00   9.94   9.94     170  169477   买盘
#
# [1257 rows x 6 columns]

# %%
a = datetime.now()
print a
print a.weekday()
# Out:
# 2017-11-11 02:38:28.455000
# 5

# %%
print time.ctime()
print type(time.ctime())
# Out:
# Sat Nov 11 02:37:38 2017
# <type 'str'>

# %%
date = datetime.strptime('2017-01-02', '%Y-%m-%d')
print date
print date.weekday()
# Out:
# 2017-01-02 00:00:00
# 0

# %%
client = pymongo.MongoClient('localhost', 27017)
collection = client[TICK_DB_NAME]['600380.SSE']
flt = {'datetime':{'$gte':datetime.strptime('2017-01-02', '%Y-%m-%d'),
                    '$lt':datetime.strptime('2017-01-03', '%Y-%m-%d')}}
cursor = collection.find(flt).sort('datetime')
for d in cursor:
    print d['datetime']
